# %% [markdown]
# # Read Overpass-API to Python Pandas Dataframe

# %% [markdown]
# The [Overpass API](http://wiki.openstreetmap.org/wiki/Overpass_API) provides access to the data behind the Openstreetmaps Map Data.
# The [Overpass-Turbo](http://overpass-turbo.eu/) is the easyiest way to test requests and get the correct code to ask the database.

# %%
import pandas as pd
import requests
import json
pd.set_option('display.max_columns', 200)

# %% [markdown]
# # Kreuzungen in OSM finden

# %% [markdown]
# Annahme: Eine Kreuzung ist dadurch definiert, dass es ein `Node` gibt, der mindestens zu 2 verschiedenen `highways` gehört.

# %% [markdown]
# Gebiet festlegen, am besten mit einer [Bounding Box](http://boundingbox.klokantech.com/)

# %%
# Get yours at: http://boundingbox.klokantech.com/
bbox = [13.57838,50.962397,13.896025,51.125713]

# Links unten
minLat = bbox[1]
minLon = bbox[0]

# Rechts oben
maxLat = bbox[3]
maxLon = bbox[2]

# %% [markdown]
# Request from [Overpass-Turbo](http://overpass-api.de/api/convert?data=%3C!--%0AThis%20has%20been%20generated%20by%20the%20overpass-turbo%20wizard.%0AThe%20original%20search%20was%3A%0A%E2%80%9CBushaltestelle%E2%80%9D%0A--%3E%0A%3Cosm-script%20output%3D%22json%22%20timeout%3D%2225%22%3E%0A%20%20%3C!--%20gather%20results%20--%3E%0A%20%20%3Cunion%3E%0A%20%20%20%20%3C!--%20query%20part%20for%3A%20%E2%80%9CBushaltestelle%E2%80%9D%20--%3E%0A%20%20%20%20%3Cquery%20type%3D%22node%22%3E%0A%20%20%20%20%20%20%3Chas-kv%20k%3D%22highway%22%20v%3D%22bus_stop%22%2F%3E%0A%20%20%20%20%20%20%3Cbbox-query%20s%3D%2250.973778188690716%22%20w%3D%2213.552322387695312%22%20n%3D%2251.12033393562918%22%20e%3D%2213.898735046386719%22%2F%3E%0A%20%20%20%20%3C%2Fquery%3E%0A%20%20%3C%2Funion%3E%0A%20%20%3C!--%20print%20results%20--%3E%0A%20%20%3Cprint%20mode%3D%22body%22%2F%3E%0A%20%20%3Crecurse%20type%3D%22down%22%2F%3E%0A%20%20%3Cprint%20mode%3D%22skeleton%22%20order%3D%22quadtile%22%2F%3E%0A%3C%2Fosm-script%3E&target=mapql)

# %%
data = 'way["highway"]' # what we are looking for!

osmrequest = {'data': '[out:json][timeout:25];(%s(%s,%s,%s,%s););out body;>;out skel qt;' % (data, minLat, minLon, maxLat, maxLon)}
osmurl = 'http://overpass-api.de/api/interpreter'

# Ask the API
osm = requests.get(osmurl, params=osmrequest)

# %% [markdown]
# The JSON can't be directyl imported to a Pandas Dataframe:
#
# Thanks to [unutbu from stackoverflow.com](http://stackoverflow.com/questions/24848416/expected-string-or-unicode-when-reading-json-with-pandas) for fiddling this out!

# %% [markdown]
# ### Get all highways

# %%
osmdata = osm.json()
osmdata = osmdata['elements']
for dct in osmdata:
    if dct['type']=='way':
        for key, val in dct['tags'].iteritems():
            dct[key] = val
        del dct['tags']
    else:
        pass # nodes

# %% [markdown]
# ### Now put everything to the Pandas Dataframe

# %%
osmdf = pd.DataFrame(osmdata)

# %% [markdown]
# ### Look at the whole Dataframe

# %%
osmdf.tail(5)
# Out:
#        FIXME access access:N3 access:backward access:conditional access:lanes  \
# 251416   NaN    NaN       NaN             NaN                NaN          NaN
# 251417   NaN    NaN       NaN             NaN                NaN          NaN
# 251418   NaN    NaN       NaN             NaN                NaN          NaN
# 251419   NaN    NaN       NaN             NaN                NaN          NaN
# 251420   NaN    NaN       NaN             NaN                NaN          NaN
#
#        access_ramp addr:city addr:country addr:door addr:postcode addr:street  \
# 251416         NaN       NaN          NaN       NaN           NaN         NaN
# 251417         NaN       NaN          NaN       NaN           NaN         NaN
# 251418         NaN       NaN          NaN       NaN           NaN         NaN
# 251419         NaN       NaN          NaN       NaN           NaN         NaN
# 251420         NaN       NaN          NaN       NaN           NaN         NaN
#
#        agricultural alt_name ambulance amenity area area:highway bench  \
# 251416          NaN      NaN       NaN     NaN  NaN          NaN   NaN
# 251417          NaN      NaN       NaN     NaN  NaN          NaN   NaN
# 251418          NaN      NaN       NaN     NaN  NaN          NaN   NaN
# 251419          NaN      NaN       NaN     NaN  NaN          NaN   NaN
# 251420          NaN      NaN       NaN     NaN  NaN          NaN   NaN
#
#        bicycle bicycle:backward bicycle:forward bicycle_parking  bin bridge  \
# 251416     NaN              NaN             NaN             NaN  NaN    NaN
# 251417     NaN              NaN             NaN             NaN  NaN    NaN
# 251418     NaN              NaN             NaN             NaN  NaN    NaN
# 251419     NaN              NaN             NaN             NaN  NaN    NaN
# 251420     NaN              NaN             NaN             NaN  NaN    NaN
#
#        bridge_name bridge_type building bus:lanes:backward bus:lanes:forward  \
# 251416         NaN         NaN      NaN                NaN               NaN
# 251417         NaN         NaN      NaN                NaN               NaN
# 251418         NaN         NaN      NaN                NaN               NaN
# 251419         NaN         NaN      NaN                NaN               NaN
# 251420         NaN         NaN      NaN                NaN               NaN
#
#        busway:right capacity capacity:disabled capacity:parent  \
# 251416          NaN      NaN               NaN             NaN
# 251417          NaN      NaN               NaN             NaN
# 251418          NaN      NaN               NaN             NaN
# 251419          NaN      NaN               NaN             NaN
# 251420          NaN      NaN               NaN             NaN
#
#        capacity:police capacity:women carriage change:lanes:backward  \
# 251416             NaN            NaN      NaN                   NaN
# 251417             NaN            NaN      NaN                   NaN
# 251418             NaN            NaN      NaN                   NaN
# 251419             NaN            NaN      NaN                   NaN
# 251420             NaN            NaN      NaN                   NaN
#
#        change:lanes:forward class:bicycle cn_tud:token color colour comment  \
# 251416                  NaN           NaN          NaN   NaN    NaN     NaN
# 251417                  NaN           NaN          NaN   NaN    NaN     NaN
# 251418                  NaN           NaN          NaN   NaN    NaN     NaN
# 251419                  NaN           NaN          NaN   NaN    NaN     NaN
# 251420                  NaN           NaN          NaN   NaN    NaN     NaN
#
#        comment:history construction construction:end construction:obstruction  \
# 251416             NaN          NaN              NaN                      NaN
# 251417             NaN          NaN              NaN                      NaN
# 251418             NaN          NaN              NaN                      NaN
# 251419             NaN          NaN              NaN                      NaN
# 251420             NaN          NaN              NaN                      NaN
#
#        construction:start conveying covered created_by crossing cutting  \
# 251416                NaN       NaN     NaN        NaN      NaN     NaN
# 251417                NaN       NaN     NaN        NaN      NaN     NaN
# 251418                NaN       NaN     NaN        NaN      NaN     NaN
# 251419                NaN       NaN     NaN        NaN      NaN     NaN
# 251420                NaN       NaN     NaN        NaN      NaN     NaN
#
#        cycleway cycleway:backward cycleway:forward cycleway:left  \
# 251416      NaN               NaN              NaN           NaN
# 251417      NaN               NaN              NaN           NaN
# 251418      NaN               NaN              NaN           NaN
# 251419      NaN               NaN              NaN           NaN
# 251420      NaN               NaN              NaN           NaN
#
#        cycleway:oneway cycleway:right cycleway:right:bicycle  \
# 251416             NaN            NaN                    NaN
# 251417             NaN            NaN                    NaN
# 251418             NaN            NaN                    NaN
# 251419             NaN            NaN                    NaN
# 251420             NaN            NaN                    NaN
#
#        cycleway:right:oneway cycleway:right:segregated  \
# 251416                   NaN                       NaN
# 251417                   NaN                       NaN
# 251418                   NaN                       NaN
# 251419                   NaN                       NaN
# 251420                   NaN                       NaN
#
#        cycleway:right:smoothness cycleway:right:surface cycleway:segregated  \
# 251416                       NaN                    NaN                 NaN
# 251417                       NaN                    NaN                 NaN
# 251418                       NaN                    NaN                 NaN
# 251419                       NaN                    NaN                 NaN
# 251420                       NaN                    NaN                 NaN
#
#        cycleway:smoothness delivery description description:de designation  \
# 251416                 NaN      NaN         NaN            NaN         NaN
# 251417                 NaN      NaN         NaN            NaN         NaN
# 251418                 NaN      NaN         NaN            NaN         NaN
# 251419                 NaN      NaN         NaN            NaN         NaN
# 251420                 NaN      NaN         NaN            NaN         NaN
#
#        destination destination:backward destination:country  \
# 251416         NaN                  NaN                 NaN
# 251417         NaN                  NaN                 NaN
# 251418         NaN                  NaN                 NaN
# 251419         NaN                  NaN                 NaN
# 251420         NaN                  NaN                 NaN
#
#        destination:forward destination:lanes destination:lanes:forward  \
# 251416                 NaN               NaN                       NaN
# 251417                 NaN               NaN                       NaN
# 251418                 NaN               NaN                       NaN
# 251419                 NaN               NaN                       NaN
# 251420                 NaN               NaN                       NaN
#
#        destination:ref destination:ref:backward destination:symbol display  \
# 251416             NaN                      NaN                NaN     NaN
# 251417             NaN                      NaN                NaN     NaN
# 251418             NaN                      NaN                NaN     NaN
# 251419             NaN                      NaN                NaN     NaN
# 251420             NaN                      NaN                NaN     NaN
#
#        disused disused:highway  dog electrified embankment emergency  \
# 251416     NaN             NaN  NaN         NaN        NaN       NaN
# 251417     NaN             NaN  NaN         NaN        NaN       NaN
# 251418     NaN             NaN  NaN         NaN        NaN       NaN
# 251419     NaN             NaN  NaN         NaN        NaN       NaN
# 251420     NaN             NaN  NaN         NaN        NaN       NaN
#
#        escalator est_width fake_gaslight  fee fenced fixme floating  \
# 251416       NaN       NaN           NaN  NaN    NaN   NaN      NaN
# 251417       NaN       NaN           NaN  NaN    NaN   NaN      NaN
# 251418       NaN       NaN           NaN  NaN    NaN   NaN      NaN
# 251419       NaN       NaN           NaN  NaN    NaN   NaN      NaN
# 251420       NaN       NaN           NaN  NaN    NaN   NaN      NaN
#
#        flood_prone food foot foot:backward foot:forward footway   ...    \
# 251416         NaN  NaN  NaN           NaN          NaN     NaN   ...
# 251417         NaN  NaN  NaN           NaN          NaN     NaN   ...
# 251418         NaN  NaN  NaN           NaN          NaN     NaN   ...
# 251419         NaN  NaN  NaN           NaN          NaN     NaN   ...
# 251420         NaN  NaN  NaN           NaN          NaN     NaN   ...
#
#        parking:lane:right:parallel passing_places pathtype placement planned  \
# 251416                         NaN            NaN      NaN       NaN     NaN
# 251417                         NaN            NaN      NaN       NaN     NaN
# 251418                         NaN            NaN      NaN       NaN     NaN
# 251419                         NaN            NaN      NaN       NaN     NaN
# 251420                         NaN            NaN      NaN       NaN     NaN
#
#        postal_code proposed  psv public_transport railway ramp ramp:bicycle  \
# 251416         NaN      NaN  NaN              NaN     NaN  NaN          NaN
# 251417         NaN      NaN  NaN              NaN     NaN  NaN          NaN
# 251418         NaN      NaN  NaN              NaN     NaN  NaN          NaN
# 251419         NaN      NaN  NaN              NaN     NaN  NaN          NaN
# 251420         NaN      NaN  NaN              NaN     NaN  NaN          NaN
#
#        ramp:bycicle ramp:stroller ramp:wheelchair recording  ref reg_name  \
# 251416          NaN           NaN             NaN       NaN  NaN      NaN
# 251417          NaN           NaN             NaN       NaN  NaN      NaN
# 251418          NaN           NaN             NaN       NaN  NaN      NaN
# 251419          NaN           NaN             NaN       NaN  NaN      NaN
# 251420          NaN           NaN             NaN       NaN  NaN      NaN
#
#        roof ruins sac_scale sac_scale_ref safety_rope  segregated service  \
# 251416  NaN   NaN       NaN           NaN         NaN         NaN     NaN
# 251417  NaN   NaN       NaN           NaN         NaN         NaN     NaN
# 251418  NaN   NaN       NaN           NaN         NaN         NaN     NaN
# 251419  NaN   NaN       NaN           NaN         NaN         NaN     NaN
# 251420  NaN   NaN       NaN           NaN         NaN         NaN     NaN
#
#        shelter short_name sidewalk sidewalk:right  ski sloped_curb smoking  \
# 251416     NaN        NaN      NaN            NaN  NaN         NaN     NaN
# 251417     NaN        NaN      NaN            NaN  NaN         NaN     NaN
# 251418     NaN        NaN      NaN            NaN  NaN         NaN     NaN
# 251419     NaN        NaN      NaN            NaN  NaN         NaN     NaN
# 251420     NaN        NaN      NaN            NaN  NaN         NaN     NaN
#
#        smoothness snowmobile source source:highway source:lit  \
# 251416        NaN        NaN    NaN            NaN        NaN
# 251417        NaN        NaN    NaN            NaN        NaN
# 251418        NaN        NaN    NaN            NaN        NaN
# 251419        NaN        NaN    NaN            NaN        NaN
# 251420        NaN        NaN    NaN            NaN        NaN
#
#        source:maxheight source:maxspeed source:maxspeed:backward  \
# 251416              NaN             NaN                      NaN
# 251417              NaN             NaN                      NaN
# 251418              NaN             NaN                      NaN
# 251419              NaN             NaN                      NaN
# 251420              NaN             NaN                      NaN
#
#         source:maxspeed:conditional source:maxspeed:forward  \
# 251416                          NaN                     NaN
# 251417                          NaN                     NaN
# 251418                          NaN                     NaN
# 251419                          NaN                     NaN
# 251420                          NaN                     NaN
#
#        source:maxspeed:hgv source:maxwidth source:name source:surface  \
# 251416                 NaN             NaN         NaN            NaN
# 251417                 NaN             NaN         NaN            NaN
# 251418                 NaN             NaN         NaN            NaN
# 251419                 NaN             NaN         NaN            NaN
# 251420                 NaN             NaN         NaN            NaN
#
#        source:width sport start_date step.condition step.height step.length  \
# 251416          NaN   NaN        NaN            NaN         NaN         NaN
# 251417          NaN   NaN        NaN            NaN         NaN         NaN
# 251418          NaN   NaN        NaN            NaN         NaN         NaN
# 251419          NaN   NaN        NaN            NaN         NaN         NaN
# 251420          NaN   NaN        NaN            NaN         NaN         NaN
#
#         step_count supervised surface surface:left surface:right  \
# 251416         NaN        NaN     NaN          NaN           NaN
# 251417         NaN        NaN     NaN          NaN           NaN
# 251418         NaN        NaN     NaN          NaN           NaN
# 251419         NaN        NaN     NaN          NaN           NaN
# 251420         NaN        NaN     NaN          NaN           NaN
#
#        surface_material symbol tactile_paving taxi tourism tourist_bus tracks  \
# 251416              NaN    NaN            NaN  NaN     NaN         NaN    NaN
# 251417              NaN    NaN            NaN  NaN     NaN         NaN    NaN
# 251418              NaN    NaN            NaN  NaN     NaN         NaN    NaN
# 251419              NaN    NaN            NaN  NaN     NaN         NaN    NaN
# 251420              NaN    NaN            NaN  NaN     NaN         NaN    NaN
#
#        tracktype traffic_calming traffic_sign trail_visibility  \
# 251416       NaN             NaN          NaN              NaN
# 251417       NaN             NaN          NaN              NaN
# 251418       NaN             NaN          NaN              NaN
# 251419       NaN             NaN          NaN              NaN
# 251420       NaN             NaN          NaN              NaN
#
#        tram:lanes:backward tram:lanes:forward tree_lined tunnel turn  \
# 251416                 NaN                NaN        NaN    NaN  NaN
# 251417                 NaN                NaN        NaN    NaN  NaN
# 251418                 NaN                NaN        NaN    NaN  NaN
# 251419                 NaN                NaN        NaN    NaN  NaN
# 251420                 NaN                NaN        NaN    NaN  NaN
#
#        turn:lanes turn:lanes:backward turn:lanes:forward  type  url vehicle  \
# 251416        NaN                 NaN                NaN  node  NaN     NaN
# 251417        NaN                 NaN                NaN  node  NaN     NaN
# 251418        NaN                 NaN                NaN  node  NaN     NaN
# 251419        NaN                 NaN                NaN  node  NaN     NaN
# 251420        NaN                 NaN                NaN  node  NaN     NaN
#
#        vehicle:backward vehicle:forward vehicle:forward:conditional  \
# 251416              NaN             NaN                         NaN
# 251417              NaN             NaN                         NaN
# 251418              NaN             NaN                         NaN
# 251419              NaN             NaN                         NaN
# 251420              NaN             NaN                         NaN
#
#        via_ferrata_scale visibility voltage waste_basket waterway website  \
# 251416               NaN        NaN     NaN          NaN      NaN     NaN
# 251417               NaN        NaN     NaN          NaN      NaN     NaN
# 251418               NaN        NaN     NaN          NaN      NaN     NaN
# 251419               NaN        NaN     NaN          NaN      NaN     NaN
# 251420               NaN        NaN     NaN          NaN      NaN     NaN
#
#        wheelchair width wikipedia wikipedia:de winter_service xmas:day_date  \
# 251416        NaN   NaN       NaN          NaN            NaN           NaN
# 251417        NaN   NaN       NaN          NaN            NaN           NaN
# 251418        NaN   NaN       NaN          NaN            NaN           NaN
# 251419        NaN   NaN       NaN          NaN            NaN           NaN
# 251420        NaN   NaN       NaN          NaN            NaN           NaN
#
#        xmas:feature xmas:name xmas:opening_hours xmas:url zone:maxspeed  \
# 251416          NaN       NaN                NaN      NaN           NaN
# 251417          NaN       NaN                NaN      NaN           NaN
# 251418          NaN       NaN                NaN      NaN           NaN
# 251419          NaN       NaN                NaN      NaN           NaN
# 251420          NaN       NaN                NaN      NaN           NaN
#
#        zone:traffic
# 251416          NaN
# 251417          NaN
# 251418          NaN
# 251419          NaN
# 251420          NaN
#
# [5 rows x 340 columns]

# %% [markdown]
# ## Look at some Tags

# %%
for tag in osmdf.highway.unique():
    print tag
# Out:
# residential
# unclassified
# living_street
# footway
# secondary
# tertiary
# track
# service
# primary
# motorway
# motorway_link
# primary_link
# cycleway
# construction
# secondary_link
# tertiary_link
# path
# trunk
# pedestrian
# steps
# trunk_link
# abandoned
# proposed
# bridleway
# elevator
# corridor
# platform
# turning_circle
# disused
# via_ferrata
# services
# crossing
# nan

# %%
for tag in osmdf.maxspeed.unique():
    print tag
# Out:
# 30
# nan
# 50
# 80
# 130
# 70
# 60
# 100
# 40
# 20
# signals
# 5
# none
# 120
# 10
# walk
# 15
# 7
# 6
# 8
# 4

# %% [markdown]
# ### The interesting ones are

# %% [markdown]
# Nur ways behalten, die auch als `highway` gekennzeichnet sind und einen Namen haben.

# %%
highwaydf = osmdf[['id', 'highway', 'lanes', 'name', 'maxspeed', 'nodes', 'ref']].dropna(subset=['name','highway'], how='any')
highwaydf.tail(5)
# Out:
#               id      highway lanes              name maxspeed  \
# 52204  293501214    secondary   NaN  Tiergartenstraße       50
# 52205  293501215    secondary   NaN  Tiergartenstraße       50
# 52206  293501216    secondary   NaN  Tiergartenstraße       50
# 52207  293501217    secondary   NaN  Tiergartenstraße       50
# 52208  293509214  residential   NaN   Lockwitzbachweg      NaN
#
#                                                    nodes  ref
# 52204                [2971077365, 796746060, 2971077364]  NaN
# 52205                 [2971077366, 30261000, 2971077365]  NaN
# 52206  [373247978, 373247792, 373247777, 373247621, 2...  NaN
# 52207  [2971077364, 18630288, 796746061, 796746056, 3...  NaN
# 52208     [773905499, 2693555506, 2261360369, 206122406]  NaN

# %% [markdown]
# ### Clean a little bit up

# %% [markdown]
# Zu kleine Straßen raus werfen

# %%
majorhighways = ['primary','secondary','secondary_link','tertiary','tertiary_link','living_street','residential']

highwaydf = highwaydf[highwaydf['highway'].isin(majorhighways)]

# %% [markdown]
# Replace `NaN` with word `unknown` and reset the index

# %%
highwaydf = highwaydf.fillna(u'unknown').reset_index(drop=True)
highwaydf.tail(5)
# Out:
#               id      highway    lanes              name maxspeed  \
# 10331  293501214    secondary  unknown  Tiergartenstraße       50
# 10332  293501215    secondary  unknown  Tiergartenstraße       50
# 10333  293501216    secondary  unknown  Tiergartenstraße       50
# 10334  293501217    secondary  unknown  Tiergartenstraße       50
# 10335  293509214  residential  unknown   Lockwitzbachweg  unknown
#
#                                                    nodes      ref
# 10331                [2971077365, 796746060, 2971077364]  unknown
# 10332                 [2971077366, 30261000, 2971077365]  unknown
# 10333  [373247978, 373247792, 373247777, 373247621, 2...  unknown
# 10334  [2971077364, 18630288, 796746061, 796746056, 3...  unknown
# 10335     [773905499, 2693555506, 2261360369, 206122406]  unknown

# %% [markdown]
# ## Now get all Nodes

# %%
nodes = []
for dct in osmdata:
    #print dct
    if dct['type']=='way':
        pass
    elif dct['type']=='node':
        nodes.append(dct)
    else:
        pass

# %%
nodesdf = pd.DataFrame(nodes)

# %%
nodesdf.tail(5)
# Out:
#                id        lat        lon  type
# 199142  253549051  51.124156  13.902017  node
# 199143  253549052  51.124026  13.900936  node
# 199144  274395738  51.123750  13.900290  node
# 199145  274395740  51.123804  13.900567  node
# 199146  274395742  51.123889  13.900869  node

# %% [markdown]
# ## Find all highways belonging to a node

# %% [markdown]
# Jeden Knoten durch gehen und schauen, ob er bei einer Straße genutzt wird. Wenn ja, die Straßen IDs zurück geben.
#
# Dauert sehr sehr lang, wenn BoundingBox groß gewählt wurde!

# %%
def gethighwayids(nodeid):
    highwayids = []
    for n, nodes in enumerate(highwaydf['nodes']):
        for nid in nodes: # alle nodes des highways
            if nid == int(nodeid):
                highwayids.append(highwaydf['id'][n])
    return highwayids

# %%
nodesdf['highwayids'] = nodesdf['id'].apply(gethighwayids)

# %%
nodesdf.tail(25)
# Out:
#                 id        lat        lon  type highwayids
# 199122   270764229  51.123438  13.899806  node         []
# 199123   274395410  51.122749  13.894424  node         []
# 199124   274395412  51.122927  13.894631  node         []
# 199125   274395415  51.123189  13.895166  node         []
# 199126   274395417  51.123400  13.895288  node         []
# 199127   274395732  51.121511  13.899288  node         []
# 199128   274395734  51.122222  13.899603  node         []
# 199129   274395736  51.123690  13.900099  node         []
# 199130   461848823  51.124011  13.899990  node         []
# 199131  1379146164  51.125336  13.894029  node         []
# 199132  1379146165  51.125316  13.894469  node         []
# 199133  1379146167  51.125316  13.894866  node         []
# 199134  1379146187  51.125336  13.895724  node         []
# 199135  1379146190  51.125350  13.896100  node         []
# 199136  1379146192  51.125282  13.896218  node         []
# 199137  1379146214  51.124030  13.896775  node         []
# 199138  1379146229  51.124676  13.896378  node         []
# 199139  1379146252  51.125155  13.896260  node         []
# 199140  1379146274  51.123917  13.896947  node         []
# 199141  1379146277  51.124259  13.896561  node         []
# 199142   253549051  51.124156  13.902017  node         []
# 199143   253549052  51.124026  13.900936  node         []
# 199144   274395738  51.123750  13.900290  node         []
# 199145   274395740  51.123804  13.900567  node         []
# 199146   274395742  51.123889  13.900869  node         []

# %% [markdown]
# ## Identify a Junction

# %% [markdown]
# Node with at least 3 different highways

# %%
def idetifyjunction(highwayids):
    #print len(highwayids)
    if len(highwayids) < 2:
        return False
    else:
        return True

# %%
nodesdf['junction'] = nodesdf['highwayids'].apply(idetifyjunction)

# %%
nodesdf.head(25)
# Out:
#            id        lat        lon  type highwayids junction
# 0   129946170  50.962859  13.562838  node         []    False
# 1   269264140  50.963054  13.563582  node         []    False
# 2   305218768  50.957774  13.570394  node         []    False
# 3   305218770  50.957870  13.570446  node         []    False
# 4   305218771  50.958005  13.570669  node         []    False
# 5   305218773  50.958275  13.571064  node         []    False
# 6   305218775  50.958335  13.571802  node         []    False
# 7   305218777  50.958465  13.572394  node         []    False
# 8   269264144  50.963436  13.574998  node         []    False
# 9   269264145  50.963352  13.575354  node         []    False
# 10  269264146  50.963120  13.576630  node         []    False
# 11  269264149  50.962504  13.578873  node         []    False
# 12  269264150  50.962255  13.578565  node         []    False
# 13  269264151  50.962077  13.578018  node         []    False
# 14  269264154  50.961925  13.577412  node         []    False
# 15  269264157  50.961931  13.576931  node         []    False
# 16  269264169  50.962001  13.576211  node         []    False
# 17  269264170  50.962169  13.575346  node         []    False
# 18  269264171  50.962375  13.574491  node         []    False
# 19  269264172  50.962706  13.573561  node         []    False
# 20  292965497  50.963424  13.575088  node         []    False
# 21  305218778  50.958627  13.572523  node         []    False
# 22  305218779  50.958654  13.572635  node         []    False
# 23  305218780  50.959016  13.572695  node         []    False
# 24  305218781  50.959400  13.572832  node         []    False

# %%
junctionsdf = nodesdf[['id','lat','lon']][nodesdf['junction']==True]

# %% [markdown]
# ## Export to CSV

# %%
junctionsdf.to_csv('junctions.csv', index=False)
print('done.')
# Out:
# done.

# %% [markdown]
# ![junctions](junctions.png)
